# %%
from stac_utils import MetadataSlowLoader, convert_timerange
import pystac
import pandas as pd

catPath = "/home/a3r/Documents/spear-flp/catalog_blue.csv"

properties = [
    "activity_id", 
    "institution_id", 
    "source_id", 
    "experiment_id",
    "frequency", 
    "realm", 
    "table_id",
    "grid_label", 
    "variable_id",
    "chunk_freq",
    "platform",
    "dimensions",
    "cell_methods",
    "standard_name"
]

# %%
def make_asset(row):

    a = pystac.Asset(
        href=row['path'],
        title="{}.{}".format(
            row["member_id"],
            row["time_range"]
        ),
        media_type="application/netcdf",
        roles=["data"]
    )

    return a

# %%
def stac_from_csv(catalog_path):
    catalog = pd.read_csv(catalog_path)
    metadata_reader = MetadataSlowLoader()
    
    for grp,df in catalog.groupby(["experiment_id","variable_id"]):
        title = grp[0] + '.' + grp[1]

        # all metadata from reading netCDF file should be same across group
        nc_metadata = metadata_reader.get(
            df.iloc[0]['path'],
            df.iloc[0].to_dict('records')[0]
        )

        print(nc_metadata)

        # times = df["time_range"].apply(convert_timerange)
        # start_time = times.min[0]
        # end_time = times.max[-1]

        # item = pystac.Item(
        #     id = title,
        #     geometry = nc_metadata.footprint,
        #     bbox = nc_metadata.bbox,
        #     properties = df.iloc[0][properties].to_dict('records')[0]
        # )

        # print(df.apply(make_asset,axis=1))

        break

# %%
stac_from_csv(catPath)
# Out:
# /tmp/ipykernel_193962/108026314.py:11: FutureWarning: Starting with pandas version 3.0 all arguments of to_dict will be keyword-only.
#   df.iloc[0].to_dict('records')[0]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 stac_from_csv(catPath)
#
# Cell In[7], line 11, in stac_from_csv(catalog_path)
#       6 title = grp[0] + '.' + grp[1]
#       8 # all metadata from reading netCDF file should be same across group
#       9 nc_metadata = metadata_reader.get(
#      10     df.iloc[0]['path'],
# ---> 11     df.iloc[0].to_dict('records')[0]
#      12 )
#      14 print(nc_metadata)
#      16 # times = df["time_range"].apply(convert_timerange)
#      17 # start_time = times.min[0]
#      18 # end_time = times.max[-1]
#    (...)     26
#      27 # print(df.apply(make_asset,axis=1))
#
# File /nbhome/Aria.Radick/conda/envs/python_venv/lib/python3.13/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /nbhome/Aria.Radick/conda/envs/python_venv/lib/python3.13/site-packages/pandas/core/series.py:2083, in Series.to_dict(self, into)
#    2054 """
#    2055 Convert Series to {label -> value} dict or dict-like object.
#    2056
#    (...)   2080 defaultdict(<class 'list'>, {0: 1, 1: 2, 2: 3, 3: 4})
#    2081 """
#    2082 # GH16122
# -> 2083 into_c = com.standardize_mapping(into)
#    2085 if is_object_dtype(self.dtype) or isinstance(self.dtype, ExtensionDtype):
#    2086     return into_c((k, maybe_box_native(v)) for k, v in self.items())
#
# File /nbhome/Aria.Radick/conda/envs/python_venv/lib/python3.13/site-packages/pandas/core/common.py:415, in standardize_mapping(into)
#     413     into = type(into)
#     414 if not issubclass(into, abc.Mapping):
# --> 415     raise TypeError(f"unsupported type: {into}")
#     416 if into == defaultdict:
#     417     raise TypeError("to_dict() only accepts initialized defaultdicts")
#
# TypeError: unsupported type: <class 'str'>
